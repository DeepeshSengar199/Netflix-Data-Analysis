# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
netflix = pd.read_csv("netflix_titles.csv")
#pd.read_excel("")      for excel file

# %%
type(netflix)
# Out:
# pandas.core.frame.DataFrame

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7789   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7790   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7791   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7792   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7793   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix.tail()
# Out:
#      show_id   type                                    title  director cast  \
# 7789   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7790   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7791   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7792   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7793   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
#
#                                     country     date_added  release_year  \
# 7789  United Kingdom, Canada, United States  March 1, 2020          2019
# 7790  United Kingdom, Canada, United States  March 1, 2020          2019
# 7791  United Kingdom, Canada, United States  March 1, 2020          2019
# 7792  United Kingdom, Canada, United States  March 1, 2020          2019
# 7793  United Kingdom, Canada, United States  March 1, 2020          2019
#
#      rating duration                        listed_in  \
# ...

# %%
netflix.shape
# Out:
# (7794, 12)

# %%
netflix.size
# Out:
# 93528

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7794 entries, 0 to 7793
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7794 non-null   object
#  1   type          7794 non-null   object
#  2   title         7794 non-null   object
#  3   director      5405 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7287 non-null   object
#  6   date_added    7784 non-null   object
#  7   release_year  7794 non-null   int64
#  8   rating        7787 non-null   object
#  9   duration      7794 non-null   object
#  10  listed_in     7794 non-null   object
#  11  description   7794 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.8+ KB

# %%
netflix.duplicated() #for check duplicate records / rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7789     True
# 7790     True
# 7791     True
# 7792     True
# 7793     True
# Length: 7794, dtype: bool

# %%
netflix.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7789     True
# 7790     True
# 7791     True
# 7792     True
# 7793     True
# Length: 7794, dtype: bool

# %%
netflix[netflix.duplicated()]
# Out:
#      show_id   type                                    title  director cast  \
# 7788   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7789   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7790   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7791   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7792   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
# 7793   s7788  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
#
#                                     country     date_added  release_year  \
# 7788  United Kingdom, Canada, United States  March 1, 2020          2019
# 7789  United Kingdom, Canada, United States  March 1, 2020          2019
# 7790  United Kingdom, Canada, United States  March 1, 2020          2019
# 7791  United Kingdom, Canada, United States  March 1, 2020          2019
# ...

# %%
netflix.drop_duplicates(inplace=True)

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7787   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7783    False  False  False     False  False    False       False
# 7784    False  False  False      True  False     True       False
# 7785    False  False  False      True  False    False       False
# 7786    False  False  False     False   True    False       False
# 7787    False  False  False     False   True    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             719
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(netflix.isnull())
# Out:
# <AxesSubplot:>

# %%
netflix.head()                              #Checking for director of show
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix['title'].str.contains('Family Man')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# Name: title, Length: 7788, dtype: bool

# %%
netflix[netflix['title'].str.contains('Family Man')]
# Out:
#     show_id   type         title       director  \
# 170    s171  Movie  A Family Man  Mark Williams
#
#                                                   cast                country  \
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
#
#             date_added  release_year rating duration listed_in  \
# 170  December 15, 2019          2016      R  110 min    Dramas
#
#                                            description
# 170  A ruthless corporate headhunter battles his ri...

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix['Date_N'] = pd.to_datetime(netflix['release_year'].astype(str))

# %%
netflix['Date_N']
# Out:
# 0      2020-01-01
# 1      2016-01-01
# 2      2011-01-01
# 3      2009-01-01
# 4      2008-01-01
#           ...
# 7783   2015-01-01
# 7784   2019-01-01
# 7785   2019-01-01
# 7786   2019-01-01
# 7787   2019-01-01
# Name: Date_N, Length: 7788, dtype: datetime64[ns]

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7787   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix['Date_N'].dt.year.value_counts().head(10)    # use head(10) for print only 10 top
# Out:
# 2018    1121
# 2017    1012
# 2019     997
# 2016     882
# 2020     868
# 2015     541
# 2014     334
# 2013     267
# 2012     219
# 2010     173
# Name: Date_N, dtype: int64

# %%
# no of movies per year
netflix['Date_N'].dt.year.value_counts().head(15).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
netflix['Date_N'].dt.year.value_counts().head(10).plot(kind='bar')
plt.title("No of Series release per years")
# Out:
# Text(0.5, 1.0, 'No of Series release per years')

# %%
netflix.groupby('type').type.count()
# Out:
# type
# Movie      5378
# TV Show    2410
# Name: type, dtype: int64

# %%
netflix['type']
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#          ...
# 7783      Movie
# 7784      Movie
# 7785    TV Show
# 7786      Movie
# 7787      Movie
# Name: type, Length: 7788, dtype: object

# %%
sns.countplot(netflix['type'])  #Movie Vs Tv shows
plt.title("Types of shows")
# Out:
# G:\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Types of shows')

# %%
# add new column 
netflix['year']  = netflix['Date_N'].dt.year

# %%
netflix['year']
# Out:
# 0       2020
# 1       2016
# 2       2011
# 3       2009
# 4       2008
#         ...
# 7783    2015
# 7784    2019
# 7785    2019
# 7786    2019
# 7787    2019
# Name: year, Length: 7788, dtype: int64

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7787   s7788    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix[(netflix['type'].str.contains('Movie')) & (netflix['year'] == 2018)]
    # movie release in 2018
# Out:
#      show_id   type                 title             director  \
# 13       s14  Movie                 2,215  Nottapon Boonprakob
# 17       s18  Movie                22-Jul      Paul Greengrass
# 20       s21  Movie  ​​Kuch Bheege Alfaaz                 Onir
# 21       s22  Movie          ​Goli Soda 2         Vijay Milton
# 31       s32  Movie     #FriendButMarried        Rako Prijanto
# ...      ...    ...                   ...                  ...
# 7751   s7752  Movie               Yucatán        Daniel Monzón
# 7764   s7765  Movie                  Zero           Aanand Rai
# 7765   s7766  Movie             Zero Hour     Robert O. Peters
# 7771   s7772  Movie                  Zion           Floyd Russ
# 7780   s7781  Movie                   Zoo         Shlok Sharma
#
#                                                    cast  \
# 13                                   Artiwara Kongmalai
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %%
netflix[(netflix['year'] == 2018)] # release in 2018
# Out:
#      show_id     type                 title             director  \
# 11       s12  TV Show                  1983                  NaN
# 13       s14    Movie                 2,215  Nottapon Boonprakob
# 16       s17  TV Show                Feb-09                  NaN
# 17       s18    Movie                22-Jul      Paul Greengrass
# 20       s21    Movie  ​​Kuch Bheege Alfaaz                 Onir
# ...      ...      ...                   ...                  ...
# 7765   s7766    Movie             Zero Hour     Robert O. Peters
# 7771   s7772    Movie                  Zion           Floyd Russ
# 7775   s7776  TV Show            Zoids Wild                  NaN
# 7777   s7778  TV Show           Zombie Dumb                  NaN
# 7780   s7781    Movie                   Zoo         Shlok Sharma
#
#                                                    cast  \
# 11    Robert Więckiewicz, Maciej Musiał, Michalina O...
# 13                                   Artiwara Kongmalai
# ...

# %%
sns.countplot(netflix[netflix['year'] == 2018]['type']) 
plt.title('TV Show vs Movie in 2018 ')
# Out:
# G:\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'TV Show vs Movie in 2018 ')

# %%
#netflix.head(2)
netflix[(netflix['country'] =='India')]

#release in india netflix
# Out:
#      show_id   type                     title            director  \
# 8         s9  Movie                       706       Shravan Kumar
# 9        s10  Movie                      1920        Vikram Bhatt
# 18       s19  Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21  Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22  Movie              ​Goli Soda 2        Vijay Milton
# ...      ...    ...                       ...                 ...
# 7764   s7765  Movie                      Zero          Aanand Rai
# 7769   s7770  Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7776   s7777  Movie                  Zokkomon    Satyajit Bhatkal
# 7780   s7781  Movie                       Zoo        Shlok Sharma
# 7783   s7784  Movie                    Zubaan         Mozez Singh
#
#                                                    cast country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
netflix['director'].value_counts().head(10)

#find who made more show and movie
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: director, dtype: int64

# %%
# graph
netflix['director'].value_counts().head(10).plot(kind='bar')
plt.ylabel('No. of release')
plt.xlabel('Directors')
plt.title('Top 10 Directors')
# Out:
# Text(0.5, 1.0, 'Top 10 Directors')

# %%
netflix.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
#list of all Dramas movies relese in india
netflix[(netflix['listed_in']== 'Dramas') & (netflix['country']=='India')]
# Out:
#      show_id   type   title        director  \
# 2367   s2368  Movie  Gemini  P.K. Baaburaaj
#
#                                                    cast country    date_added  \
# 2367  Esther Anil, Sijoy Varghese, Renji Panicker, T...   India  July 1, 2018
#
#       release_year rating duration listed_in  \
# 2367          2018  TV-PG  130 min    Dramas
#
#                                             description     Date_N  year
# 2367  Despite growing up with traits that set her ap... 2018-01-01  2018

# %%
# remove null values from dataframe
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             719
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# Date_N             0
# year               0
# dtype: int64

# %%
 netflix.dropna(inplace = True)
netflix.isnull().sum()               #This is also called cleaning of dataframe
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# Date_N          0
# year            0
# dtype: int64

# %%
netflix.shape
# Out:
# (4808, 14)

# %%
# different rating on netflix
netflix['rating'].value_counts()
# Out:
# TV-MA       1665
# TV-14       1133
# R            654
# TV-PG        413
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: rating, dtype: int64

# %%
uni_ratings = netflix['rating'].unique()

# %%
uni_ratings
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix['rating'].nunique()
# return total unique values
# Out:
# 14

# %%
netflix.head(2)
#netflix.
#netflix max durations
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie  07:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added  release_year rating duration  \
# 1  December 23, 2016          2016  TV-MA   93 min
# 2  December 20, 2018          2011      R   78 min
#
#                              listed_in  \
# 1         Dramas, International Movies
# 2  Horror Movies, International Movies
#
#                                          description     Date_N  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-01-01  2016
# 2  When an army recruit is found dead, his fellow... 2011-01-01  2011

# %%
# creating dataframe of tv show 
Movie_DF = netflix[netflix['type']=='Movie']
netflix[netflix['type']=='TV Show']
# Out:
#      show_id     type            title            director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7385   s7386  TV Show          Valeria       Inma Torrente
# 7400   s7401  TV Show           Velvet        Carlos Sedes
# 7492   s7493  TV Show   Watership Down          Noam Murro
# 7666   s7667  TV Show    World of Winx      Iginio Straffi
# 7721   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %%
Movie_DF['country'].value_counts()
# Out:
# United States                                                   1627
# India                                                            827
# United Kingdom                                                   155
# Canada                                                           101
# Egypt                                                             87
#                                                                 ...
# Netherlands, Belgium                                               1
# United Kingdom, Denmark, Canada, Croatia                           1
# Thailand, United States                                            1
# United States, South Korea                                         1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: country, Length: 536, dtype: int64

# %%
Movie_DF['country'].value_counts().head(10).plot(kind='bar')

#plot graph
# Out:
# <AxesSubplot:>
